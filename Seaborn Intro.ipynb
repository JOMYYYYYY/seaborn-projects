# %% [markdown]
# # Matplotlib

# %%
from matplotlib import pyplot as plt

# %%
x = [10, 20, 30, 40]
y = [0, 15, 10, 25]

# %%
plt.plot(x, y);

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %%
sns.set()

# %%
plt.plot(x, y);

# %%
sns.set_style("white")

# %%
plt.plot(x, y);

# %% [markdown]
# # Version

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.8.0'

# %%
sns.__version__
# Out:
# '0.13.0'

# %% [markdown]
# # Seaborn with Pandas
