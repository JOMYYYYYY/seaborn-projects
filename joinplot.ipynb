# %% [markdown]
# # seaborn: joinplot (联合分布 边缘分布)

# %%
import seaborn as sns
from matplotlib import pyplot as pyplot
import matplotlib

# %%
sns.__version__
# Out:
# '0.13.0'

# %%
matplotlib.__version__
# Out:
# '3.8.0'

# %%
geyser = sns.load_dataset('geyser')

# %%
geyser.head()
# Out:
#    duration  waiting   kind
# 0     3.600       79   long
# 1     1.800       54  short
# 2     3.333       74   long
# 3     2.283       62  short
# 4     4.533       85   long

# %%
geyser.shape
# Out:
# (272, 3)

# %% [markdown]
# ## basic

# %%
sns.set_style('darkgrid')

# %%
sns.jointplot(x=geyser.waiting, y=geyser.duration)

# %%
sns.jointplot(x='waiting', y='duration', data=geyser)

# %% [markdown]
# ## plot kind:
# There are currently six kinds of jointplots allowed in seaborn:
# * scatter (defualt)
# * kde
# * reg
# * hist
# * hex
# * resid

# %% [markdown]
# ### scater (default)

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='scatter')

# %% [markdown]
# ### kde

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='kde')

# %% [markdown]
# ### reg

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='reg')

# %% [markdown]
# ### hist

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='hist')
# just like a heatmap

# %% [markdown]
# ## return joinplot

# %%
g = sns.jointplot(x='waiting', y='duration', data=geyser)

# %%
type(g)
# Out:
# seaborn.axisgrid.JointGrid

# %%
g = sns.jointplot(x='waiting', y='duration', data=geyser)
g.plot_joint(sns.kdeplot, color='gray', levels=5)

# %% [markdown]
# ## catagorical value

# %%
geyser.head()
# Out:
#    duration  waiting   kind
# 0     3.600       79   long
# 1     1.800       54  short
# 2     3.333       74   long
# 3     2.283       62  short
# 4     4.533       85   long

# %%
g = sns.jointplot(x='waiting', y='duration', data=geyser,
                  hue='kind')

# %%
g = sns.jointplot(x='waiting', y='duration', data=geyser, kind='kde',
                  hue='kind')

# %% [markdown]
# ## advanced styling

# %% [markdown]
# ### color palette

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              color='green')

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              hue='kind',
              palette='Spectral')

# %% [markdown]
# ### height space ratio

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,hue='kind',palette='Spectral',
              height=7,
              space=0.1,
              ratio=9)

# %% [markdown]
# ## key words

# %% [markdown]
# ### join_kws

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              joint_kws={'marker': 5})

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='reg',
              joint_kws={'marker': 5})

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='reg',
              joint_kws={'marker': 5, 'ci': None, 'order': 2})

# %% [markdown]
# ### marginal_kws

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='reg',
              marginal_kws={'color': 'xkcd:golden'})

# %%
sns.jointplot(x='waiting', y='duration', data=geyser,
              kind='kde',
              marginal_kws={'color': 'xkcd:golden', 'lw': 4, 'fill': True})

# %% [markdown]
# [teaching sorce](https://www.youtube.com/watch?v=Hey1EAtgduQ&t=611s&ab_channel=KimberlyFessel)
